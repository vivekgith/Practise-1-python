# %% [markdown]
# # USER INPUT

# %% [markdown]
#  # Print function always change line .

# %% [markdown]
# # Input Function Always return STR Value.

# %%
x = input("Enter a Number")
# Out:
# Enter a Number 22

# %%
x = input()
# Out:
#  22

# %%
x = int(input("Enter a Number"))
y = int(input("Enter a Number"))
z = x + y
print("sum of",x, "and", y, "is",z)
# Out:
# Enter a Number 222
# Enter a Number 345
# sum of 222 and 345 is 567
